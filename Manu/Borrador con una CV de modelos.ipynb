# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/tp2datostrain/train.csv
# /kaggle/input/tp2datostrain/test.csv
# /kaggle/input/pingsound/PING - Sound effect.mp3

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from category_encoders import CountEncoder
from sklearn.model_selection import train_test_split
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# %%
from IPython.display import Audio
sound_file = '/kaggle/input/pingsound/PING - Sound effect.mp3'
def ping():
    display(Audio(sound_file, autoplay=True))

# %%
import pandas as pd
test = pd.read_csv("../input/tp2datostrain/test.csv")
train = pd.read_csv("../input/tp2datostrain/train.csv")

# %%
dfCheto = pd.concat([train,test], sort=False)
dfCheto = train
#dfCheto['precio'] = SimpleImputer(strategy='median').fit_transform(dfCheto[['precio']])
df = dfCheto.copy()

# %%
ciudades = list(dfCheto["ciudad"].unique())
tipos_de_propiedad = list(dfCheto["tipodepropiedad"].unique())
provincia = list(dfCheto["provincia"].unique())
categorias  = [provincia, tipos_de_propiedad, ciudades]

# %%
df.columns
# Out:
# Index(['id', 'titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad',
#        'provincia', 'antiguedad', 'habitaciones', 'garages', 'banos',
#        'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'fecha',
#        'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas',
#        'centroscomercialescercanos', 'precio'],
#       dtype='object')

# %%
df.provincia.isna().sum()
# Out:
# 155

# %%
aux2 = dfCheto[['ciudad', 'provincia']].copy()
aux2.dropna(inplace = True)
aux2 = aux2.groupby(['provincia']).agg(lambda x:x.provincia.value_counts().index[0]).reset_index().set_index('ciudad')
dicc_ciudadPorPcia = aux2.T.to_dict('records').copy()[0]
dicc_ciudadPorPcia['CUALQUIERA'] = 'CUALQUIERCIUDAD'
df['ciudad'] =df['ciudad'].fillna('CUALQUIERA')
df['provincia'] = df['provincia'].fillna(df['ciudad'].map(dicc_ciudadPorPcia))

# %%
df.provincia.fillna('provinciaVacia',inplace=True)

# %%
df['provincia'].isna().sum()
# Out:
# 0

# %%
aux2 = dfCheto[['ciudad', 'provincia']].copy()
aux2 = aux2.groupby(['provincia']).agg(lambda x:x.provincia.value_counts().index[0]).reset_index().set_index('ciudad')
aux2.head()
dicc_ciudadMasFrecuentePorPcia = aux2.T.to_dict('records').copy()[0]
dicc_invertido = dict(map(reversed, dicc_ciudadMasFrecuentePorPcia.items()))
df.ciudad.fillna(df.provincia.map(dicc_invertido),inplace=True);
df.ciudad.isna().sum()
# Out:
# 0

# %%
df.ciudad.fillna('ciudadVacia',inplace=True)

# %%
df.tipodepropiedad.fillna('tipoVacio',inplace=True)
'''
auxmetros = df[['tipodepropiedad','metrostotales']].copy()
auxmetros = auxmetros.groupby('tipodepropiedad')['metrostotales'].mean().sort_values().reset_index()
lista = sorted(auxmetros.metrostotales.tolist())
lista_2 = [0]*len(lista)
for i,numero in enumerate(lista):
    if i == 0: lista_2[i] = (0,numero)
    else:
        lista_2[i] = (lista[i-1],lista[i])
rangoMetros = pd.Series(lista_2).sort_values()
auxmetros['rangoMetros'] = rangoMetros
auxmetros = auxmetros.set_index('tipodepropiedad').drop(columns='metrostotales')
dicc_tipoDeProp = auxmetros.T.to_dict('records').copy()[0]
def mapearMetros(metrostotales,dicc_tipoDeProp):
    for clave in dicc_tipoDeProp:
        if metrostotales >= dicc_tipoDeProp[clave][0] and metrostotales < dicc_tipoDeProp[clave][1]: return clave
    return 'Casa'
df.tipodepropiedad.fillna(df.metrostotales.map(lambda x: mapearMetros(x,dicc_tipoDeProp)),inplace=True);
df.tipodepropiedad.isna().sum()
'''
# Out:
# "\nauxmetros = df[['tipodepropiedad','metrostotales']].copy()\nauxmetros = auxmetros.groupby('tipodepropiedad')['metrostotales'].mean().sort_values().reset_index()\nlista = sorted(auxmetros.metrostotales.tolist())\nlista_2 = [0]*len(lista)\nfor i,numero in enumerate(lista):\n    if i == 0: lista_2[i] = (0,numero)\n    else:\n        lista_2[i] = (lista[i-1],lista[i])\nrangoMetros = pd.Series(lista_2).sort_values()\nauxmetros['rangoMetros'] = rangoMetros\nauxmetros = auxmetros.set_index('tipodepropiedad').drop(columns='metrostotales')\ndicc_tipoDeProp = auxmetros.T.to_dict('records').copy()[0]\ndef mapearMetros(metrostotales,dicc_tipoDeProp):\n    for clave in dicc_tipoDeProp:\n        if metrostotales >= dicc_tipoDeProp[clave][0] and metrostotales < dicc_tipoDeProp[clave][1]: return clave\n    return 'Casa'\ndf.tipodepropiedad.fillna(df.metrostotales.map(lambda x: mapearMetros(x,dicc_tipoDeProp)),inplace=True);\ndf.tipodepropiedad.isna().sum()\n"

# %%
aux2 = dfCheto[['idzona', 'ciudad']].copy()
aux2.dropna(inplace = True)
aux2 = aux2.groupby('ciudad').agg({'idzona':'median'})
ids = aux2.T.to_dict('records').copy()
ids = ids[0]
#df.idzona.fillna(df.ciudad.map(ids), inplace = True)

# %%
df['idzona'] = SimpleImputer(strategy='most_frequent').fit_transform(df[['idzona']])

# %%
aux = dfCheto[['lat', 'ciudad']].copy()
aux.dropna(inplace = True)
aux = aux.groupby('ciudad').agg({'lat':'mean'})
lats = aux.T.to_dict('records').copy()
lats = lats[0]
#df.lat.fillna(df.ciudad.map(lats), inplace = True)

# %%
df['lat'] = SimpleImputer(strategy='most_frequent').fit_transform(df[['lat']])

# %%
aux = dfCheto[['lng', 'ciudad']].copy()
aux.dropna(inplace = True)
aux = aux.groupby('ciudad').agg({'lng':'mean'})
lngs = aux.T.to_dict('records').copy()
lngs = lngs[0]
#df.lng.fillna(df.ciudad.map(lngs), inplace = True)

# %%
df['lng'] = SimpleImputer(strategy='most_frequent').fit_transform(df[['lng']])

# %%
aux = dfCheto[['tipodepropiedad', 'habitaciones']].copy()
aux.dropna(inplace = True)
aux = aux.groupby('tipodepropiedad').agg({'habitaciones':'median'})
habts = aux.T.to_dict('records').copy()
habts = habts[0]
#df.habitaciones.fillna(df.tipodepropiedad.map(habts), inplace = True)

# %%
df['habitaciones'] = SimpleImputer(strategy='most_frequent').fit_transform(df[['habitaciones']])

# %%
aux = dfCheto[['tipodepropiedad', 'garages']].copy()
aux.dropna(inplace = True)
aux = aux.groupby('tipodepropiedad').agg({'garages':'median'})
habts = aux.T.to_dict('records').copy()
habts = habts[0]
#df.garages.fillna(df.tipodepropiedad.map(habts), inplace = True)

# %%
df.garages.fillna(0, inplace=True)

# %%
df.drop(columns=['direccion'], inplace=True)

# %%
aux = dfCheto[['antiguedad', 'ciudad']].copy()
aux.dropna(inplace = True)
aux = aux.groupby('ciudad').agg({'antiguedad':'mean'})
lngs = aux.T.to_dict('records').copy()
lngs = lngs[0]
#df.antiguedad.fillna(df.ciudad.map(lngs), inplace = True)

# %%
df['antiguedad'] = SimpleImputer(strategy='most_frequent').fit_transform(df[['antiguedad']])

# %%
aux = dfCheto[['banos', 'tipodepropiedad']].copy()
aux.dropna(inplace = True)
aux = aux.groupby('tipodepropiedad').agg({'banos':'median'})
lngs = aux.T.to_dict('records').copy()
lngs = lngs[0]
#df.banos.fillna(df.tipodepropiedad.map(lngs), inplace = True)

# %%
df.banos.fillna(1, inplace=True)

# %%
aux = df.copy()

# %%
aux.metrostotales.fillna(0, inplace=True)
aux.metroscubiertos.fillna(0, inplace =True)
aux['metrostotalesCorregidos'] = aux[['metrostotales', 'metroscubiertos']].max(axis=1)
aux['metroscubiertosCorregidos'] = aux[['metrostotales', 'metroscubiertos']].min(axis=1)
df['metrostotales'] = aux['metrostotalesCorregidos']
df['metroscubiertos'] = aux['metroscubiertosCorregidos']

# %%
df['fecha'] = pd.to_datetime(df['fecha'])
df['dia'] = df.fecha.dt.day
df['mes'] = df.fecha.dt.month
df['anio'] = df.fecha.dt.year
df.drop(columns=['fecha'], inplace=True)

# %%
df['publicacionesPorCiudad'] = CountEncoder().fit_transform(df['ciudad'])

# %%
df['publicacionesPorProvincia'] = CountEncoder().fit_transform(df['provincia'])

# %%
df['publicacionesPorTipo'] = CountEncoder().fit_transform(df['tipodepropiedad'])
df['publicacionesPorZona'] = CountEncoder().fit_transform(df['idzona'])
df['publicacionesPorBanos'] = CountEncoder().fit_transform(df['banos'])
df['publicacionesPorHabitaciones'] = CountEncoder().fit_transform(df['habitaciones'])
df['publicacionesPorAntiguedad'] = CountEncoder().fit_transform(df['antiguedad'])

# %%
df[['tipodepropiedad','provincia','ciudad']].isna().sum()
# Out:
# tipodepropiedad    0
# provincia          0
# ciudad             0
# dtype: int64

# %% [markdown]
# ### Datos por grupo

# %%
df['promedioAntiguedadZona'] = df.groupby('idzona').agg({'antiguedad':'mean'})
df['promedioAntiguedadCiudad'] = df.groupby('ciudad').agg({'antiguedad':'mean'})
df['promedioHabitacionesZona'] = df.groupby('idzona').agg({'habitaciones':'mean'})
df['promedioHabitacionesCiudad'] = df.groupby('ciudad').agg({'habitaciones':'mean'})
df['promedioMetrosCubiertosZona'] = df.groupby('idzona').agg({'metroscubiertos': 'mean'})
df['promedioMetrosCubiertosCiudad'] = df.groupby('ciudad').agg({'metroscubiertos': 'mean'})
df['promedioMetrosTotalesZona'] = df.groupby('idzona').agg({'metrostotales': 'mean'})
df['promedioMetrosTotalesCiudad'] = df.groupby('ciudad').agg({'metrostotales': 'mean'})
df['promedioPrecioPorProvincia'] = df.groupby('provincia').agg({'precio': 'mean'})
df['promedioPrecioPorIdzona'] = df.groupby('idzona').agg({'precio': 'mean'})
df['promedioPrecioPorCiudad'] = df.groupby('ciudad').agg({'precio': 'mean'})

# %%
aux = train[['provincia', 'ciudad', 'idzona','precio', 'metrostotales']].copy()
aux['precioXM2'] = aux['precio'] / aux['metrostotales']
aux.groupby('provincia').agg({'precioXM2': 'mean'})
# Out:
#                           precioXM2
# provincia
# Aguascalientes          8191.787234
# Baja California Norte   5968.995969
# Baja California Sur     6485.002327
# Campeche                8697.074357
# Chiapas                11020.039292
# Chihuahua               7651.501242
# Coahuila                7042.142596
# Colima                  7313.212268
# Distrito Federal       24011.411266
# Durango                 6367.351148
# Edo. de México         14146.115299
# Guanajuato             10582.114212
# Guerrero               14678.291470
# Hidalgo                 8276.294305
# Jalisco                13570.913738
# Michoacán               9414.540506
# Morelos                10017.064217
# Nayarit                 9511.649444
# Nuevo León             13197.894574
# Oaxaca                  9647.169256
# Puebla                 12935.559997
# Querétaro              10542.430314
# Quintana Roo           12673.585135
# San luis Potosí        10459.465715
# Sinaloa                 9168.727438
# Sonora                  6657.331157
# Tabasco                13366.246230
# Tamaulipas              8399.849454
# Tlaxcala                7495.538034
# Veracruz               10858.965150
# Yucatán                 8358.432465
# Zacatecas               9923.806834

# %% [markdown]
# ### Texto

# %%
df.titulo.fillna('', inplace=True)
df.descripcion.fillna('', inplace=True)
df["titulo_descripcion"] = df["titulo"].astype(str) + " " + df["descripcion"].astype(str)
#Como tiene algunos nulos los relleno con cadenas vaicas
df["titulo_descripcion"].fillna("",inplace = True)
#REMUEVO LA PUNTUACION
import string
print(string.punctuation)
tabla = {}
for c in string.punctuation + "¿¡":
    tabla[ord(c)] = None
def sacar_puntuacion(s):
    return s.translate(tabla)
df["titulo_descripcion"] = df["titulo_descripcion"].apply(sacar_puntuacion)
#Agrego los primeros features
df["nro_palabras"] = df["titulo_descripcion"].apply(lambda x: len(x.split(" ")))
df["nro_caracteres"] = df["titulo_descripcion"].apply(lambda x: len(x))
df["long_prom_palabra"] = df["nro_caracteres"] / df["nro_palabras"]

def llenarDiccionario(diccionario,descripcion):
    for palabra in descripcion.split():
        diccionario[palabra] = diccionario.get(palabra,0) + 1
        
def generarDiccionario(df2):
    dicc = {}
    for descripcion in df2['titulo_descripcion']:
        if isinstance(descripcion,str): llenarDiccionario(dicc,descripcion)
    return dicc
contador_palabras = generarDiccionario(df)

#Elimino las stopwords = palabras vacias que no suman nada
from nltk.corpus import stopwords
palabras_vacias = stopwords.words('spanish')

for palabra  in palabras_vacias:
    if palabra in contador_palabras:
        del contador_palabras[palabra]
ordenados = sorted(contador_palabras.items(),key = lambda x: -x[1])
top_50 = dict(ordenados[:50])

#Nuevos features
def contar_palabras_en_top(texto):
    palabras = texto.split()
    cont = 0
    for palabra in palabras:
        if palabra in top_50:
            cont += 1
    return cont
df["nro_palabras_mas_comunes"] = df["titulo_descripcion"].apply(contar_palabras_en_top)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
df.columns
# Out:
# Index(['id', 'titulo', 'descripcion', 'tipodepropiedad', 'ciudad', 'provincia',
#        'antiguedad', 'habitaciones', 'garages', 'banos', 'metroscubiertos',
#        'metrostotales', 'idzona', 'lat', 'lng', 'gimnasio', 'usosmultiples',
#        'piscina', 'escuelascercanas', 'centroscomercialescercanos', 'precio',
#        'dia', 'mes', 'anio', 'publicacionesPorCiudad',
#        'publicacionesPorProvincia', 'publicacionesPorTipo',
#        'publicacionesPorZona', 'publicacionesPorBanos',
#        'publicacionesPorHabitaciones', 'publicacionesPorAntiguedad',
#        'promedioAntiguedadZona', 'promedioAntiguedadCiudad',
#        'promedioHabitacionesZona', 'promedioHabitacionesCiudad',
#        'titulo_descripcion', 'nro_palabras', 'nro_caracteres',
#        'long_prom_palabra', 'nro_palabras_mas_comunes'],
#       dtype='object')

# %%
features = [    
        'id', 'antiguedad',
       'habitaciones', 'garages', 'banos', 'metroscubiertos', 'metrostotales',
       'idzona', 'lat', 'lng', 'gimnasio', 'usosmultiples', 'piscina',
       'escuelascercanas', 'centroscomercialescercanos',
       'dia', 'mes', 'anio',
        #Canti de publicaciones
        'publicacionesPorCiudad',
       'publicacionesPorProvincia', 'publicacionesPorTipo',
        'publicacionesPorZona','publicacionesPorBanos',
        'publicacionesPorHabitaciones', 'publicacionesPorAntiguedad',
            
        #Texto
        "nro_palabras", "nro_caracteres", "long_prom_palabra", "nro_palabras_mas_comunes",
         #Promedios
        'promedioAntiguedadZona', 'promedioAntiguedadCiudad',
        'promedioHabitacionesZona', 'promedioHabitacionesCiudad',
        'promedioMetrosCubiertosZona','promedioMetrosCubiertosCiudad',
        'promedioMetrosTotalesZona', 'promedioMetrosTotalesCiudad', 
        'promedioPrecioPorProvincia', 'promedioPrecioPorIdzona', 
        'promedioPrecioPorCiudad',
            #'promedioPxM2Provincia',
         'ciudad','tipodepropiedad', 'provincia', ]

# %%
transformador_categorias = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', categories = categorias)),
])

transformador_numeros = Pipeline(steps=[('a', SimpleImputer(strategy = 'median'))])

# %%
def obtenerFeaturesCategoricos(features):
    l = []
    for feature in features:
        if not np.issubdtype(df[feature].dtype, np.number):
            l.append(feature)
    return l

num_features = list(df[features].select_dtypes(include=[np.number]).columns)

cat_features = list(obtenerFeaturesCategoricos(features))
print ("Features numericos:", num_features, '\nFeatures categoricos: ', cat_features)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', transformador_numeros, num_features),
        ('cat', transformador_categorias, cat_features)
    ])
# Out:
# Features numericos: ['id', 'antiguedad', 'habitaciones', 'garages', 'banos', 'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas', 'centroscomercialescercanos', 'dia', 'mes', 'anio', 'publicacionesPorCiudad', 'publicacionesPorProvincia', 'publicacionesPorTipo', 'publicacionesPorZona', 'publicacionesPorBanos', 'publicacionesPorHabitaciones', 'publicacionesPorAntiguedad', 'nro_palabras', 'nro_caracteres', 'long_prom_palabra', 'nro_palabras_mas_comunes', 'promedioAntiguedadZona', 'promedioAntiguedadCiudad', 'promedioHabitacionesZona', 'promedioHabitacionesCiudad', 'promedioMetrosCubiertosZona', 'promedioMetrosCubiertosCiudad', 'promedioMetrosTotalesZona', 'promedioMetrosTotalesCiudad', 'promedioPrecioPorProvincia', 'promedioPrecioPorIdzona', 'promedioPrecioPorCiudad']
# Features categoricos:  ['ciudad', 'tipodepropiedad', 'provincia']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', transformador_numeros, num_features),
        ('cat', transformador_categorias, cat_features)
    ])

# %%
model = xgb.XGBRegressor(#learning_rate= 0.1,n_estimators= 1000,scale_pos_weight= 2,max_depth= 5,min_child_weight= 3,gamma= 0.0,colsample_bytree= 0.75,                     subsample= 0.7,colsample_bylevel= 0.65, 
    learning_rate= 0.1,n_estimators= 2000,scale_pos_weight= 2,max_depth= 5,min_child_weight= 5,gamma= 0.0,colsample_bytree= 0.75,subsample= 0.7,colsample_bylevel= 0.65, 
    tree_method='gpu_hist', gpu_id=0, eval_metric = "mae")

# %%
entrenamiento = df.head(240000).copy()

# %%
prueba = df.tail(60000).copy()

# %%
prueba.drop(columns=['precio'], inplace=True)

# %%
train_x = entrenamiento[features].copy()
train_y = entrenamiento.precio.copy()
#train_x, test_x, train_y, test_y = train_test_split(train_x, train_y,train_size=0.8, test_size=0.2, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
RF_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('classifier', RandomForestClassifier(n_estimators = 1000, max_depth = 5))
                             ])

# %%
#X_train,X_test,y_train,y_test = train_test_split(train_x, train_y,test_size=0.3, random_state = 0)
#clf = RF_pipeline.fit(X_train, y_train)
#importancia_de_features = RF_pipeline.steps[1][1].feature_importances_
#for feature in sorted(zip(importancia_de_features,features),reverse=True):
  #print(feature)

# %%
train_x.tipodepropiedad = train_x.tipodepropiedad.astype(str)
train_x.provincia = train_x.provincia.astype(str)
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model)
                             ])

# %%
my_pipeline.fit(train_x, train_y)

# %%
preds = my_pipeline.predict(train_x)

# %%
ping()
mean_absolute_error(preds, train_y)

# %%
preds_finales = my_pipeline.predict(prueba)

# %%
res = pd.DataFrame(preds_finales, index=prueba.id, columns=['precio'])
res.reset_index(inplace=True)
res.columns = ["id", "target"]
display(res.head())
# RMSLE=1.0249284784393988 ?


# import the modules we'll need
from IPython.display import HTML
import base64

# function that takes in a dataframe and creates a text link to  
# download it (will only work for files < 2MB or so)
def create_download_link(df, title = "Download CSV file", filename = "knn-results.csv"):  
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# create a link to download the dataframe
create_download_link(res)

# %%
x_train, x_val, y_train, y_val = train_test_split(train_x, train_y,train_size=0.8, random_state = 0)
x_train_procesado = preprocessor.fit_transform(x_train)
x_val_procesado = preprocessor.fit_transform(x_val)
my_pipeline.fit(x_train,y_train, model__eval_set=[(x_train_procesado, y_train.to_numpy()), (x_val_procesado, y_val.to_numpy())])
preds = my_pipeline.predict(x_val)
predictions = [round(value) for value in preds]
# Out:
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [17:50:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:2.28024e+06	validation_1-mae:2.27622e+06
# [1]	validation_0-mae:2.05356e+06	validation_1-mae:2.05001e+06
# [2]	validation_0-mae:1.85379e+06	validation_1-mae:1.85088e+06
# [3]	validation_0-mae:1.67843e+06	validation_1-mae:1.6757e+06
# [4]	validation_0-mae:1.52522e+06	validation_1-mae:1.52316e+06
# [5]	validation_0-mae:1.39654e+06	validation_1-mae:1.39557e+06
# [6]	validation_0-mae:1.28516e+06	validation_1-mae:1.28516e+06
# [7]	validation_0-mae:1.19233e+06	validation_1-mae:1.19344e+06
# [8]	validation_0-mae:1.11277e+06	validation_1-mae:1.11498e+06
# [9]	validation_0-mae:1.05193e+06	validation_1-mae:1.05533e+06
# [10]	validation_0-mae:1.00024e+06	validation_1-mae:1.0045e+06
# [11]	validation_0-mae:959302	validation_1-mae:964389
# [12]	validation_0-mae:926501	validation_1-mae:931876
# [13]	validation_0-mae:896438	validation_1-mae:902532
# [14]	validation_0-mae:871948	validation_1-mae:878129
# [15]	validation_0-mae:853565	validation_1-mae:860093
# [16]	validation_0-mae:839281	validation_1-mae:845790
# [17]	validation_0-mae:825749	validation_1-mae:832164
# [18]	validation_0-mae:816386	validation_1-mae:822806
# [19]	validation_0-mae:808235	validation_1-mae:814581
# [20]	validation_0-mae:801370	validation_1-mae:807409
# [21]	validation_0-mae:793936	validation_1-mae:799911
# [22]	validation_0-mae:787144	validation_1-mae:793056
# [23]	validation_0-mae:780986	validation_1-mae:786678
# [24]	validation_0-mae:775151	validation_1-mae:780707
# [25]	validation_0-mae:769175	validation_1-mae:774901
# [26]	validation_0-mae:765616	validation_1-mae:771209
# [27]	validation_0-mae:762261	validation_1-mae:767832
# [28]	validation_0-mae:759621	validation_1-mae:765197
# [29]	validation_0-mae:756626	validation_1-mae:762083
# [30]	validation_0-mae:753164	validation_1-mae:758419
# [31]	validation_0-mae:750885	validation_1-mae:756208
# [32]	validation_0-mae:748808	validation_1-mae:753992
# [33]	validation_0-mae:746825	validation_1-mae:751997
# [34]	validation_0-mae:743725	validation_1-mae:748803
# [35]	validation_0-mae:742276	validation_1-mae:747488
# [36]	validation_0-mae:739847	validation_1-mae:744925
# [37]	validation_0-mae:737645	validation_1-mae:742578
# [38]	validation_0-mae:735998	validation_1-mae:740820
# [39]	validation_0-mae:731951	validation_1-mae:736876
# [40]	validation_0-mae:730227	validation_1-mae:735218
# [41]	validation_0-mae:729354	validation_1-mae:734468
# [42]	validation_0-mae:728280	validation_1-mae:733444
# [43]	validation_0-mae:726640	validation_1-mae:731882
# [44]	validation_0-mae:725252	validation_1-mae:730412
# [45]	validation_0-mae:723779	validation_1-mae:728922
# [46]	validation_0-mae:722630	validation_1-mae:727862
# [47]	validation_0-mae:721407	validation_1-mae:726599
# [48]	validation_0-mae:719973	validation_1-mae:725160
# [49]	validation_0-mae:718655	validation_1-mae:723850
# [50]	validation_0-mae:717630	validation_1-mae:722912
# [51]	validation_0-mae:715836	validation_1-mae:721244
# [52]	validation_0-mae:714213	validation_1-mae:719562
# [53]	validation_0-mae:712949	validation_1-mae:718358
# [54]	validation_0-mae:711511	validation_1-mae:716923
# [55]	validation_0-mae:710267	validation_1-mae:715703
# [56]	validation_0-mae:708722	validation_1-mae:714187
# [57]	validation_0-mae:707353	validation_1-mae:712818
# [58]	validation_0-mae:706035	validation_1-mae:711596
# [59]	validation_0-mae:704880	validation_1-mae:710545
# [60]	validation_0-mae:703964	validation_1-mae:709637
# [61]	validation_0-mae:701982	validation_1-mae:707747
# [62]	validation_0-mae:700970	validation_1-mae:706774
# [63]	validation_0-mae:700271	validation_1-mae:706074
# [64]	validation_0-mae:699343	validation_1-mae:705175
# [65]	validation_0-mae:697676	validation_1-mae:703545
# [66]	validation_0-mae:696413	validation_1-mae:702358
# [67]	validation_0-mae:695227	validation_1-mae:701197
# [68]	validation_0-mae:693942	validation_1-mae:700053
# [69]	validation_0-mae:692601	validation_1-mae:698812
# [70]	validation_0-mae:691770	validation_1-mae:697970
# [71]	validation_0-mae:690728	validation_1-mae:697014
# [72]	validation_0-mae:689394	validation_1-mae:695629
# [73]	validation_0-mae:688714	validation_1-mae:695047
# [74]	validation_0-mae:687446	validation_1-mae:693881
# [75]	validation_0-mae:686558	validation_1-mae:692982
# [76]	validation_0-mae:685948	validation_1-mae:692401
# [77]	validation_0-mae:685481	validation_1-mae:692026
# [78]	validation_0-mae:684710	validation_1-mae:691213
# [79]	validation_0-mae:684092	validation_1-mae:690544
# [80]	validation_0-mae:683508	validation_1-mae:689967
# [81]	validation_0-mae:682441	validation_1-mae:688887
# [82]	validation_0-mae:681757	validation_1-mae:688179
# [83]	validation_0-mae:680778	validation_1-mae:687190
# [84]	validation_0-mae:679606	validation_1-mae:686168
# [85]	validation_0-mae:678515	validation_1-mae:685143
# [86]	validation_0-mae:677692	validation_1-mae:684387
# [87]	validation_0-mae:677332	validation_1-mae:684098
# [88]	validation_0-mae:676338	validation_1-mae:683072
# [89]	validation_0-mae:675615	validation_1-mae:682360
# [90]	validation_0-mae:674874	validation_1-mae:681535
# [91]	validation_0-mae:674336	validation_1-mae:681060
# [92]	validation_0-mae:673895	validation_1-mae:680569
# [93]	validation_0-mae:672901	validation_1-mae:679712
# [94]	validation_0-mae:672143	validation_1-mae:679026
# [95]	validation_0-mae:671332	validation_1-mae:678234
# [96]	validation_0-mae:670787	validation_1-mae:677746
# [97]	validation_0-mae:669868	validation_1-mae:676777
# [98]	validation_0-mae:669473	validation_1-mae:676474
# [99]	validation_0-mae:668853	validation_1-mae:675916
# [100]	validation_0-mae:668547	validation_1-mae:675689
# [101]	validation_0-mae:668371	validation_1-mae:675509
# [102]	validation_0-mae:667980	validation_1-mae:675247
# [103]	validation_0-mae:667542	validation_1-mae:674834
# [104]	validation_0-mae:666099	validation_1-mae:673446
# [105]	validation_0-mae:665439	validation_1-mae:672772
# [106]	validation_0-mae:664544	validation_1-mae:671912
# [107]	validation_0-mae:664189	validation_1-mae:671655
# [108]	validation_0-mae:662760	validation_1-mae:670172
# [109]	validation_0-mae:662110	validation_1-mae:669547
# [110]	validation_0-mae:661642	validation_1-mae:669117
# [111]	validation_0-mae:661254	validation_1-mae:668780
# [112]	validation_0-mae:660488	validation_1-mae:668083
# [113]	validation_0-mae:660243	validation_1-mae:667880
# [114]	validation_0-mae:659631	validation_1-mae:667340
# [115]	validation_0-mae:659337	validation_1-mae:667099
# [116]	validation_0-mae:658818	validation_1-mae:666631
# [117]	validation_0-mae:658431	validation_1-mae:666291
# [118]	validation_0-mae:657991	validation_1-mae:665989
# [119]	validation_0-mae:657659	validation_1-mae:665753
# [120]	validation_0-mae:656527	validation_1-mae:664604
# [121]	validation_0-mae:655858	validation_1-mae:663919
# [122]	validation_0-mae:654803	validation_1-mae:662894
# [123]	validation_0-mae:653658	validation_1-mae:661806
# [124]	validation_0-mae:653207	validation_1-mae:661406
# [125]	validation_0-mae:652426	validation_1-mae:660643
# [126]	validation_0-mae:651776	validation_1-mae:660110
# [127]	validation_0-mae:651523	validation_1-mae:659921
# [128]	validation_0-mae:651172	validation_1-mae:659643
# [129]	validation_0-mae:650750	validation_1-mae:659213
# [130]	validation_0-mae:650381	validation_1-mae:658918
# [131]	validation_0-mae:650178	validation_1-mae:658734
# [132]	validation_0-mae:649852	validation_1-mae:658460
# [133]	validation_0-mae:649351	validation_1-mae:658038
# [134]	validation_0-mae:647882	validation_1-mae:656531
# [135]	validation_0-mae:647448	validation_1-mae:656135
# [136]	validation_0-mae:646762	validation_1-mae:655516
# [137]	validation_0-mae:646182	validation_1-mae:654951
# [138]	validation_0-mae:645845	validation_1-mae:654727
# [139]	validation_0-mae:645687	validation_1-mae:654620
# [140]	validation_0-mae:645557	validation_1-mae:654524
# [141]	validation_0-mae:644103	validation_1-mae:653101
# [142]	validation_0-mae:643672	validation_1-mae:652717
# [143]	validation_0-mae:643408	validation_1-mae:652527
# [144]	validation_0-mae:643290	validation_1-mae:652446
# [145]	validation_0-mae:643067	validation_1-mae:652292
# [146]	validation_0-mae:642617	validation_1-mae:651910
# [147]	validation_0-mae:642352	validation_1-mae:651663
# [148]	validation_0-mae:641531	validation_1-mae:650746
# [149]	validation_0-mae:641174	validation_1-mae:650447
# [150]	validation_0-mae:640767	validation_1-mae:650074
# [151]	validation_0-mae:640319	validation_1-mae:649629
# [152]	validation_0-mae:639747	validation_1-mae:649027
# [153]	validation_0-mae:639572	validation_1-mae:648827
# [154]	validation_0-mae:639383	validation_1-mae:648636
# [155]	validation_0-mae:639011	validation_1-mae:648327
# [156]	validation_0-mae:638113	validation_1-mae:647423
# [157]	validation_0-mae:637658	validation_1-mae:646993
# [158]	validation_0-mae:637025	validation_1-mae:646416
# [159]	validation_0-mae:636802	validation_1-mae:646171
# [160]	validation_0-mae:635719	validation_1-mae:645122
# [161]	validation_0-mae:635271	validation_1-mae:644795
# [162]	validation_0-mae:635087	validation_1-mae:644636
# [163]	validation_0-mae:634705	validation_1-mae:644240
# [164]	validation_0-mae:634433	validation_1-mae:644001
# [165]	validation_0-mae:634255	validation_1-mae:643923
# [166]	validation_0-mae:634051	validation_1-mae:643780
# [167]	validation_0-mae:633796	validation_1-mae:643714
# [168]	validation_0-mae:633568	validation_1-mae:643530
# [169]	validation_0-mae:633177	validation_1-mae:643191
# [170]	validation_0-mae:632774	validation_1-mae:642901
# [171]	validation_0-mae:632501	validation_1-mae:642692
# [172]	validation_0-mae:632320	validation_1-mae:642522
# [173]	validation_0-mae:632172	validation_1-mae:642475
# [174]	validation_0-mae:632059	validation_1-mae:642430
# [175]	validation_0-mae:631881	validation_1-mae:642336
# [176]	validation_0-mae:631815	validation_1-mae:642295
# [177]	validation_0-mae:631392	validation_1-mae:641877
# [178]	validation_0-mae:630908	validation_1-mae:641449
# [179]	validation_0-mae:630763	validation_1-mae:641317
# [180]	validation_0-mae:630502	validation_1-mae:641098
# [181]	validation_0-mae:630099	validation_1-mae:640783
# [182]	validation_0-mae:629494	validation_1-mae:640292
# [183]	validation_0-mae:629321	validation_1-mae:640201
# [184]	validation_0-mae:628967	validation_1-mae:639973
# [185]	validation_0-mae:628643	validation_1-mae:639643
# [186]	validation_0-mae:628315	validation_1-mae:639373
# [187]	validation_0-mae:627983	validation_1-mae:639104
# [188]	validation_0-mae:627480	validation_1-mae:638620
# [189]	validation_0-mae:627230	validation_1-mae:638409
# [190]	validation_0-mae:627082	validation_1-mae:638304
# [191]	validation_0-mae:626829	validation_1-mae:638116
# [192]	validation_0-mae:626663	validation_1-mae:637968
# [193]	validation_0-mae:626325	validation_1-mae:637766
# [194]	validation_0-mae:625932	validation_1-mae:637438
# [195]	validation_0-mae:625756	validation_1-mae:637276
# [196]	validation_0-mae:625509	validation_1-mae:637083
# [197]	validation_0-mae:625458	validation_1-mae:637093
# [198]	validation_0-mae:625183	validation_1-mae:636904
# [199]	validation_0-mae:625027	validation_1-mae:636784
# [200]	validation_0-mae:624593	validation_1-mae:636430
# [201]	validation_0-mae:624463	validation_1-mae:636330
# [202]	validation_0-mae:624016	validation_1-mae:635920
# [203]	validation_0-mae:623872	validation_1-mae:635791
# [204]	validation_0-mae:623543	validation_1-mae:635515
# [205]	validation_0-mae:623289	validation_1-mae:635330
# [206]	validation_0-mae:622783	validation_1-mae:634836
# [207]	validation_0-mae:622585	validation_1-mae:634698
# [208]	validation_0-mae:622135	validation_1-mae:634282
# [209]	validation_0-mae:621989	validation_1-mae:634185
# [210]	validation_0-mae:621751	validation_1-mae:634067
# [211]	validation_0-mae:621515	validation_1-mae:633870
# [212]	validation_0-mae:621102	validation_1-mae:633480
# [213]	validation_0-mae:620886	validation_1-mae:633282
# [214]	validation_0-mae:620584	validation_1-mae:633109
# [215]	validation_0-mae:620420	validation_1-mae:633032
# [216]	validation_0-mae:620130	validation_1-mae:632832
# [217]	validation_0-mae:619972	validation_1-mae:632786
# [218]	validation_0-mae:619775	validation_1-mae:632672
# [219]	validation_0-mae:619165	validation_1-mae:632159
# [220]	validation_0-mae:619075	validation_1-mae:632125
# [221]	validation_0-mae:618566	validation_1-mae:631573
# [222]	validation_0-mae:618361	validation_1-mae:631422
# [223]	validation_0-mae:618244	validation_1-mae:631290
# [224]	validation_0-mae:617985	validation_1-mae:631086
# [225]	validation_0-mae:617774	validation_1-mae:630926
# [226]	validation_0-mae:617400	validation_1-mae:630639
# [227]	validation_0-mae:617125	validation_1-mae:630395
# [228]	validation_0-mae:616933	validation_1-mae:630288
# [229]	validation_0-mae:616591	validation_1-mae:629978
# [230]	validation_0-mae:616057	validation_1-mae:629538
# [231]	validation_0-mae:615830	validation_1-mae:629322
# [232]	validation_0-mae:615690	validation_1-mae:629257
# [233]	validation_0-mae:615654	validation_1-mae:629296
# [234]	validation_0-mae:615401	validation_1-mae:629112
# [235]	validation_0-mae:615333	validation_1-mae:629087
# [236]	validation_0-mae:615034	validation_1-mae:628803
# [237]	validation_0-mae:614916	validation_1-mae:628749
# [238]	validation_0-mae:614580	validation_1-mae:628404
# [239]	validation_0-mae:614424	validation_1-mae:628311
# [240]	validation_0-mae:614009	validation_1-mae:627959
# [241]	validation_0-mae:613853	validation_1-mae:627837
# [242]	validation_0-mae:613547	validation_1-mae:627539
# [243]	validation_0-mae:613087	validation_1-mae:627170
# [244]	validation_0-mae:612815	validation_1-mae:626950
# [245]	validation_0-mae:612572	validation_1-mae:626790
# [246]	validation_0-mae:612445	validation_1-mae:626786
# [247]	validation_0-mae:612173	validation_1-mae:626569
# [248]	validation_0-mae:611738	validation_1-mae:626147
# [249]	validation_0-mae:611535	validation_1-mae:625991
# [250]	validation_0-mae:611363	validation_1-mae:625872
# [251]	validation_0-mae:610851	validation_1-mae:625298
# [252]	validation_0-mae:610623	validation_1-mae:625088
# [253]	validation_0-mae:610545	validation_1-mae:625101
# [254]	validation_0-mae:610280	validation_1-mae:624854
# [255]	validation_0-mae:609904	validation_1-mae:624526
# [256]	validation_0-mae:609838	validation_1-mae:624536
# [257]	validation_0-mae:609679	validation_1-mae:624417
# [258]	validation_0-mae:609127	validation_1-mae:623961
# [259]	validation_0-mae:608913	validation_1-mae:623842
# [260]	validation_0-mae:608703	validation_1-mae:623650
# [261]	validation_0-mae:608548	validation_1-mae:623560
# [262]	validation_0-mae:608394	validation_1-mae:623441
# [263]	validation_0-mae:608110	validation_1-mae:623269
# [264]	validation_0-mae:607970	validation_1-mae:623169
# [265]	validation_0-mae:607609	validation_1-mae:622928
# [266]	validation_0-mae:607503	validation_1-mae:622850
# [267]	validation_0-mae:607038	validation_1-mae:622438
# [268]	validation_0-mae:606903	validation_1-mae:622350
# [269]	validation_0-mae:606622	validation_1-mae:622165
# [270]	validation_0-mae:606140	validation_1-mae:621750
# [271]	validation_0-mae:606103	validation_1-mae:621765
# [272]	validation_0-mae:605759	validation_1-mae:621458
# [273]	validation_0-mae:605372	validation_1-mae:621117
# [274]	validation_0-mae:605207	validation_1-mae:621002
# [275]	validation_0-mae:604966	validation_1-mae:620798
# [276]	validation_0-mae:604910	validation_1-mae:620775
# [277]	validation_0-mae:604704	validation_1-mae:620589
# [278]	validation_0-mae:604504	validation_1-mae:620488
# [279]	validation_0-mae:604393	validation_1-mae:620408
# [280]	validation_0-mae:604185	validation_1-mae:620300
# [281]	validation_0-mae:604097	validation_1-mae:620290
# [282]	validation_0-mae:603776	validation_1-mae:620047
# [283]	validation_0-mae:603586	validation_1-mae:619923
# [284]	validation_0-mae:603417	validation_1-mae:619802
# [285]	validation_0-mae:603390	validation_1-mae:619792
# [286]	validation_0-mae:603256	validation_1-mae:619710
# [287]	validation_0-mae:603096	validation_1-mae:619662
# [288]	validation_0-mae:603020	validation_1-mae:619652
# [289]	validation_0-mae:602798	validation_1-mae:619515
# [290]	validation_0-mae:602603	validation_1-mae:619376
# [291]	validation_0-mae:602441	validation_1-mae:619286
# [292]	validation_0-mae:602239	validation_1-mae:619115
# [293]	validation_0-mae:602086	validation_1-mae:618992
# [294]	validation_0-mae:601835	validation_1-mae:618834
# [295]	validation_0-mae:601670	validation_1-mae:618781
# [296]	validation_0-mae:601468	validation_1-mae:618653
# [297]	validation_0-mae:601364	validation_1-mae:618651
# [298]	validation_0-mae:601325	validation_1-mae:618661
# [299]	validation_0-mae:601300	validation_1-mae:618654
# [300]	validation_0-mae:600987	validation_1-mae:618318
# [301]	validation_0-mae:600702	validation_1-mae:618038
# [302]	validation_0-mae:600565	validation_1-mae:617932
# [303]	validation_0-mae:600358	validation_1-mae:617787
# [304]	validation_0-mae:600056	validation_1-mae:617593
# [305]	validation_0-mae:599959	validation_1-mae:617600
# [306]	validation_0-mae:599741	validation_1-mae:617433
# [307]	validation_0-mae:599628	validation_1-mae:617388
# [308]	validation_0-mae:599457	validation_1-mae:617256
# [309]	validation_0-mae:598947	validation_1-mae:616812
# [310]	validation_0-mae:598718	validation_1-mae:616592
# [311]	validation_0-mae:598593	validation_1-mae:616522
# [312]	validation_0-mae:598474	validation_1-mae:616482
# [313]	validation_0-mae:598316	validation_1-mae:616410
# [314]	validation_0-mae:598213	validation_1-mae:616382
# [315]	validation_0-mae:598048	validation_1-mae:616323
# [316]	validation_0-mae:597624	validation_1-mae:615886
# [317]	validation_0-mae:597589	validation_1-mae:615901
# [318]	validation_0-mae:597349	validation_1-mae:615738
# [319]	validation_0-mae:597259	validation_1-mae:615716
# [320]	validation_0-mae:597169	validation_1-mae:615720
# [321]	validation_0-mae:596828	validation_1-mae:615410
# [322]	validation_0-mae:596570	validation_1-mae:615223
# [323]	validation_0-mae:596421	validation_1-mae:615143
# [324]	validation_0-mae:596406	validation_1-mae:615165
# [325]	validation_0-mae:596133	validation_1-mae:614953
# [326]	validation_0-mae:595898	validation_1-mae:614781
# [327]	validation_0-mae:595601	validation_1-mae:614572
# [328]	validation_0-mae:595340	validation_1-mae:614313
# [329]	validation_0-mae:595285	validation_1-mae:614290
# [330]	validation_0-mae:595197	validation_1-mae:614275
# [331]	validation_0-mae:595082	validation_1-mae:614200
# [332]	validation_0-mae:594881	validation_1-mae:614011
# [333]	validation_0-mae:594808	validation_1-mae:614009
# [334]	validation_0-mae:594743	validation_1-mae:614014
# [335]	validation_0-mae:594673	validation_1-mae:613987
# [336]	validation_0-mae:594476	validation_1-mae:613803
# [337]	validation_0-mae:594362	validation_1-mae:613713
# [338]	validation_0-mae:594260	validation_1-mae:613708
# [339]	validation_0-mae:594154	validation_1-mae:613657
# [340]	validation_0-mae:593759	validation_1-mae:613296
# [341]	validation_0-mae:593674	validation_1-mae:613288
# [342]	validation_0-mae:593440	validation_1-mae:613110
# [343]	validation_0-mae:593236	validation_1-mae:612951
# [344]	validation_0-mae:593050	validation_1-mae:612803
# [345]	validation_0-mae:592899	validation_1-mae:612701
# [346]	validation_0-mae:592707	validation_1-mae:612583
# [347]	validation_0-mae:592525	validation_1-mae:612474
# [348]	validation_0-mae:592464	validation_1-mae:612454
# [349]	validation_0-mae:592159	validation_1-mae:612223
# [350]	validation_0-mae:592084	validation_1-mae:612193
# [351]	validation_0-mae:591922	validation_1-mae:612118
# [352]	validation_0-mae:591581	validation_1-mae:611856
# [353]	validation_0-mae:591471	validation_1-mae:611794
# [354]	validation_0-mae:591416	validation_1-mae:611769
# [355]	validation_0-mae:591279	validation_1-mae:611640
# [356]	validation_0-mae:591106	validation_1-mae:611458
# [357]	validation_0-mae:591016	validation_1-mae:611434
# [358]	validation_0-mae:590766	validation_1-mae:611279
# [359]	validation_0-mae:590743	validation_1-mae:611289
# [360]	validation_0-mae:590609	validation_1-mae:611168
# [361]	validation_0-mae:590495	validation_1-mae:611126
# [362]	validation_0-mae:590338	validation_1-mae:611002
# [363]	validation_0-mae:590240	validation_1-mae:610980
# [364]	validation_0-mae:590123	validation_1-mae:610872
# [365]	validation_0-mae:589632	validation_1-mae:610321
# [366]	validation_0-mae:589551	validation_1-mae:610311
# [367]	validation_0-mae:589453	validation_1-mae:610247
# [368]	validation_0-mae:589366	validation_1-mae:610231
# [369]	validation_0-mae:589304	validation_1-mae:610221
# [370]	validation_0-mae:589103	validation_1-mae:610070
# [371]	validation_0-mae:589068	validation_1-mae:610068
# [372]	validation_0-mae:588924	validation_1-mae:609952
# [373]	validation_0-mae:588756	validation_1-mae:609808
# [374]	validation_0-mae:588699	validation_1-mae:609766
# [375]	validation_0-mae:588495	validation_1-mae:609602
# [376]	validation_0-mae:588372	validation_1-mae:609537
# [377]	validation_0-mae:588321	validation_1-mae:609516
# [378]	validation_0-mae:588096	validation_1-mae:609404
# [379]	validation_0-mae:588003	validation_1-mae:609318
# [380]	validation_0-mae:587965	validation_1-mae:609320
# [381]	validation_0-mae:587915	validation_1-mae:609331
# [382]	validation_0-mae:587840	validation_1-mae:609295
# [383]	validation_0-mae:587764	validation_1-mae:609248
# [384]	validation_0-mae:587702	validation_1-mae:609229
# [385]	validation_0-mae:587660	validation_1-mae:609227
# [386]	validation_0-mae:587486	validation_1-mae:609086
# [387]	validation_0-mae:587321	validation_1-mae:609003
# [388]	validation_0-mae:586958	validation_1-mae:608625
# [389]	validation_0-mae:586701	validation_1-mae:608463
# [390]	validation_0-mae:586633	validation_1-mae:608441
# [391]	validation_0-mae:586525	validation_1-mae:608347
# [392]	validation_0-mae:586320	validation_1-mae:608237
# [393]	validation_0-mae:586070	validation_1-mae:608061
# [394]	validation_0-mae:585922	validation_1-mae:607989
# [395]	validation_0-mae:585876	validation_1-mae:607991
# [396]	validation_0-mae:585860	validation_1-mae:608011
# [397]	validation_0-mae:585784	validation_1-mae:607970
# [398]	validation_0-mae:585535	validation_1-mae:607787
# [399]	validation_0-mae:585431	validation_1-mae:607714
# [400]	validation_0-mae:585349	validation_1-mae:607724
# [401]	validation_0-mae:585101	validation_1-mae:607456
# [402]	validation_0-mae:584999	validation_1-mae:607431
# [403]	validation_0-mae:584946	validation_1-mae:607406
# [404]	validation_0-mae:584803	validation_1-mae:607373
# [405]	validation_0-mae:584507	validation_1-mae:607134
# [406]	validation_0-mae:584344	validation_1-mae:607033
# [407]	validation_0-mae:584233	validation_1-mae:606961
# [408]	validation_0-mae:584109	validation_1-mae:606920
# [409]	validation_0-mae:583778	validation_1-mae:606620
# [410]	validation_0-mae:583568	validation_1-mae:606465
# [411]	validation_0-mae:583355	validation_1-mae:606320
# [412]	validation_0-mae:583078	validation_1-mae:606100
# [413]	validation_0-mae:582819	validation_1-mae:605822
# [414]	validation_0-mae:582695	validation_1-mae:605751
# [415]	validation_0-mae:582630	validation_1-mae:605726
# [416]	validation_0-mae:582417	validation_1-mae:605566
# [417]	validation_0-mae:582349	validation_1-mae:605546
# [418]	validation_0-mae:582224	validation_1-mae:605435
# [419]	validation_0-mae:582000	validation_1-mae:605236
# [420]	validation_0-mae:581889	validation_1-mae:605140
# [421]	validation_0-mae:581749	validation_1-mae:605064
# [422]	validation_0-mae:581700	validation_1-mae:605057
# [423]	validation_0-mae:581539	validation_1-mae:604924
# [424]	validation_0-mae:581370	validation_1-mae:604804
# [425]	validation_0-mae:581251	validation_1-mae:604711
# [426]	validation_0-mae:581180	validation_1-mae:604663
# [427]	validation_0-mae:581030	validation_1-mae:604540
# [428]	validation_0-mae:580968	validation_1-mae:604498
# [429]	validation_0-mae:580895	validation_1-mae:604474
# [430]	validation_0-mae:580709	validation_1-mae:604351
# [431]	validation_0-mae:580620	validation_1-mae:604281
# [432]	validation_0-mae:580491	validation_1-mae:604220
# [433]	validation_0-mae:580336	validation_1-mae:604096
# [434]	validation_0-mae:580145	validation_1-mae:603923
# [435]	validation_0-mae:580057	validation_1-mae:603918
# [436]	validation_0-mae:580006	validation_1-mae:603881
# [437]	validation_0-mae:579827	validation_1-mae:603776
# [438]	validation_0-mae:579742	validation_1-mae:603752
# [439]	validation_0-mae:579654	validation_1-mae:603734
# [440]	validation_0-mae:579502	validation_1-mae:603658
# [441]	validation_0-mae:579429	validation_1-mae:603656
# [442]	validation_0-mae:579358	validation_1-mae:603582
# [443]	validation_0-mae:579146	validation_1-mae:603393
# [444]	validation_0-mae:579033	validation_1-mae:603281
# [445]	validation_0-mae:578904	validation_1-mae:603219
# [446]	validation_0-mae:578714	validation_1-mae:603094
# [447]	validation_0-mae:578498	validation_1-mae:602932
# [448]	validation_0-mae:578327	validation_1-mae:602823
# [449]	validation_0-mae:578264	validation_1-mae:602843
# [450]	validation_0-mae:578210	validation_1-mae:602847
# [451]	validation_0-mae:578092	validation_1-mae:602794
# [452]	validation_0-mae:577984	validation_1-mae:602758
# [453]	validation_0-mae:577908	validation_1-mae:602751
# [454]	validation_0-mae:577783	validation_1-mae:602695
# [455]	validation_0-mae:577657	validation_1-mae:602578
# [456]	validation_0-mae:577553	validation_1-mae:602512
# [457]	validation_0-mae:577510	validation_1-mae:602493
# [458]	validation_0-mae:577396	validation_1-mae:602418
# [459]	validation_0-mae:577307	validation_1-mae:602374
# [460]	validation_0-mae:577171	validation_1-mae:602307
# [461]	validation_0-mae:577007	validation_1-mae:602206
# [462]	validation_0-mae:576926	validation_1-mae:602200
# [463]	validation_0-mae:576833	validation_1-mae:602160
# [464]	validation_0-mae:576682	validation_1-mae:602051
# [465]	validation_0-mae:576575	validation_1-mae:602006
# [466]	validation_0-mae:576532	validation_1-mae:602021
# [467]	validation_0-mae:576426	validation_1-mae:601934
# [468]	validation_0-mae:576238	validation_1-mae:601839
# [469]	validation_0-mae:576203	validation_1-mae:601842
# [470]	validation_0-mae:576089	validation_1-mae:601758
# [471]	validation_0-mae:576013	validation_1-mae:601756
# [472]	validation_0-mae:575863	validation_1-mae:601670
# [473]	validation_0-mae:575809	validation_1-mae:601688
# [474]	validation_0-mae:575703	validation_1-mae:601670
# [475]	validation_0-mae:575609	validation_1-mae:601642
# [476]	validation_0-mae:575539	validation_1-mae:601623
# [477]	validation_0-mae:575388	validation_1-mae:601498
# [478]	validation_0-mae:575321	validation_1-mae:601475
# [479]	validation_0-mae:575072	validation_1-mae:601300
# [480]	validation_0-mae:574950	validation_1-mae:601218
# [481]	validation_0-mae:574711	validation_1-mae:601020
# [482]	validation_0-mae:574622	validation_1-mae:601026
# [483]	validation_0-mae:574589	validation_1-mae:601039
# [484]	validation_0-mae:574461	validation_1-mae:600974
# [485]	validation_0-mae:574371	validation_1-mae:600956
# [486]	validation_0-mae:574256	validation_1-mae:600933
# [487]	validation_0-mae:574259	validation_1-mae:600938
# [488]	validation_0-mae:574156	validation_1-mae:600953
# [489]	validation_0-mae:574030	validation_1-mae:600876
# [490]	validation_0-mae:573980	validation_1-mae:600905
# [491]	validation_0-mae:573892	validation_1-mae:600848
# [492]	validation_0-mae:573736	validation_1-mae:600742
# [493]	validation_0-mae:573616	validation_1-mae:600683
# [494]	validation_0-mae:573525	validation_1-mae:600633
# [495]	validation_0-mae:573382	validation_1-mae:600549
# [496]	validation_0-mae:573293	validation_1-mae:600490
# [497]	validation_0-mae:573203	validation_1-mae:600408
# [498]	validation_0-mae:573050	validation_1-mae:600274
# [499]	validation_0-mae:572923	validation_1-mae:600184
# [500]	validation_0-mae:572664	validation_1-mae:599986
# [501]	validation_0-mae:572594	validation_1-mae:599960
# [502]	validation_0-mae:572409	validation_1-mae:599876
# [503]	validation_0-mae:572151	validation_1-mae:599645
# [504]	validation_0-mae:572101	validation_1-mae:599657
# [505]	validation_0-mae:572032	validation_1-mae:599650
# [506]	validation_0-mae:571965	validation_1-mae:599627
# [507]	validation_0-mae:571901	validation_1-mae:599615
# [508]	validation_0-mae:571845	validation_1-mae:599598
# [509]	validation_0-mae:571711	validation_1-mae:599526
# [510]	validation_0-mae:571641	validation_1-mae:599532
# [511]	validation_0-mae:571568	validation_1-mae:599518
# [512]	validation_0-mae:571461	validation_1-mae:599478
# [513]	validation_0-mae:571161	validation_1-mae:599200
# [514]	validation_0-mae:571111	validation_1-mae:599214
# [515]	validation_0-mae:571026	validation_1-mae:599179
# [516]	validation_0-mae:570894	validation_1-mae:599090
# [517]	validation_0-mae:570724	validation_1-mae:598974
# [518]	validation_0-mae:570636	validation_1-mae:598909
# [519]	validation_0-mae:570499	validation_1-mae:598824
# [520]	validation_0-mae:570348	validation_1-mae:598697
# [521]	validation_0-mae:570237	validation_1-mae:598671
# [522]	validation_0-mae:570035	validation_1-mae:598491
# [523]	validation_0-mae:569953	validation_1-mae:598453
# [524]	validation_0-mae:569913	validation_1-mae:598470
# [525]	validation_0-mae:569822	validation_1-mae:598420
# [526]	validation_0-mae:569766	validation_1-mae:598413
# [527]	validation_0-mae:569661	validation_1-mae:598363
# [528]	validation_0-mae:569633	validation_1-mae:598362
# [529]	validation_0-mae:569544	validation_1-mae:598366
# [530]	validation_0-mae:569465	validation_1-mae:598347
# [531]	validation_0-mae:569412	validation_1-mae:598322
# [532]	validation_0-mae:569163	validation_1-mae:598073
# [533]	validation_0-mae:569074	validation_1-mae:598035
# [534]	validation_0-mae:568988	validation_1-mae:598021
# [535]	validation_0-mae:568846	validation_1-mae:597944
# [536]	validation_0-mae:568713	validation_1-mae:597882
# [537]	validation_0-mae:568409	validation_1-mae:597612
# [538]	validation_0-mae:568391	validation_1-mae:597625
# [539]	validation_0-mae:568314	validation_1-mae:597551
# [540]	validation_0-mae:568192	validation_1-mae:597549
# [541]	validation_0-mae:568122	validation_1-mae:597512
# [542]	validation_0-mae:567931	validation_1-mae:597355
# [543]	validation_0-mae:567802	validation_1-mae:597309
# [544]	validation_0-mae:567756	validation_1-mae:597320
# [545]	validation_0-mae:567530	validation_1-mae:597083
# [546]	validation_0-mae:567496	validation_1-mae:597068
# [547]	validation_0-mae:567305	validation_1-mae:596949
# [548]	validation_0-mae:567266	validation_1-mae:596936
# [549]	validation_0-mae:567167	validation_1-mae:596921
# [550]	validation_0-mae:567080	validation_1-mae:596889
# [551]	validation_0-mae:566941	validation_1-mae:596818
# [552]	validation_0-mae:566884	validation_1-mae:596811
# [553]	validation_0-mae:566679	validation_1-mae:596617
# [554]	validation_0-mae:566620	validation_1-mae:596635
# [555]	validation_0-mae:566549	validation_1-mae:596633
# [556]	validation_0-mae:566473	validation_1-mae:596596
# [557]	validation_0-mae:566403	validation_1-mae:596609
# [558]	validation_0-mae:566321	validation_1-mae:596596
# [559]	validation_0-mae:566145	validation_1-mae:596444
# [560]	validation_0-mae:566052	validation_1-mae:596398
# [561]	validation_0-mae:565945	validation_1-mae:596330
# [562]	validation_0-mae:565861	validation_1-mae:596299
# [563]	validation_0-mae:565798	validation_1-mae:596302
# [564]	validation_0-mae:565686	validation_1-mae:596261
# [565]	validation_0-mae:565643	validation_1-mae:596239
# [566]	validation_0-mae:565595	validation_1-mae:596215
# [567]	validation_0-mae:565535	validation_1-mae:596234
# [568]	validation_0-mae:565455	validation_1-mae:596209
# [569]	validation_0-mae:565396	validation_1-mae:596214
# [570]	validation_0-mae:565358	validation_1-mae:596216
# [571]	validation_0-mae:565240	validation_1-mae:596158
# [572]	validation_0-mae:565139	validation_1-mae:596135
# [573]	validation_0-mae:565076	validation_1-mae:596174
# [574]	validation_0-mae:564912	validation_1-mae:596064
# [575]	validation_0-mae:564874	validation_1-mae:596048
# [576]	validation_0-mae:564778	validation_1-mae:595990
# [577]	validation_0-mae:564706	validation_1-mae:595928
# [578]	validation_0-mae:564658	validation_1-mae:595912
# [579]	validation_0-mae:564552	validation_1-mae:595878
# [580]	validation_0-mae:564469	validation_1-mae:595848
# [581]	validation_0-mae:564276	validation_1-mae:595672
# [582]	validation_0-mae:564204	validation_1-mae:595674
# [583]	validation_0-mae:564127	validation_1-mae:595633
# [584]	validation_0-mae:563991	validation_1-mae:595548
# [585]	validation_0-mae:563940	validation_1-mae:595537
# [586]	validation_0-mae:563850	validation_1-mae:595452
# [587]	validation_0-mae:563811	validation_1-mae:595491
# [588]	validation_0-mae:563724	validation_1-mae:595450
# [589]	validation_0-mae:563616	validation_1-mae:595381
# [590]	validation_0-mae:563541	validation_1-mae:595329
# [591]	validation_0-mae:563489	validation_1-mae:595313
# [592]	validation_0-mae:563388	validation_1-mae:595272
# [593]	validation_0-mae:563209	validation_1-mae:595120
# [594]	validation_0-mae:563170	validation_1-mae:595137
# [595]	validation_0-mae:563126	validation_1-mae:595162
# [596]	validation_0-mae:563029	validation_1-mae:595147
# [597]	validation_0-mae:562835	validation_1-mae:594999
# [598]	validation_0-mae:562709	validation_1-mae:594995
# [599]	validation_0-mae:562654	validation_1-mae:594960
# [600]	validation_0-mae:562534	validation_1-mae:594891
# [601]	validation_0-mae:562480	validation_1-mae:594879
# [602]	validation_0-mae:562379	validation_1-mae:594826
# [603]	validation_0-mae:562279	validation_1-mae:594804
# [604]	validation_0-mae:562205	validation_1-mae:594814
# [605]	validation_0-mae:562165	validation_1-mae:594806
# [606]	validation_0-mae:562119	validation_1-mae:594830
# [607]	validation_0-mae:562013	validation_1-mae:594816
# [608]	validation_0-mae:561914	validation_1-mae:594796
# [609]	validation_0-mae:561838	validation_1-mae:594769
# [610]	validation_0-mae:561720	validation_1-mae:594671
# [611]	validation_0-mae:561622	validation_1-mae:594633
# [612]	validation_0-mae:561588	validation_1-mae:594647
# [613]	validation_0-mae:561551	validation_1-mae:594641
# [614]	validation_0-mae:561474	validation_1-mae:594609
# [615]	validation_0-mae:561375	validation_1-mae:594506
# [616]	validation_0-mae:561258	validation_1-mae:594441
# [617]	validation_0-mae:561114	validation_1-mae:594339
# [618]	validation_0-mae:561054	validation_1-mae:594340
# [619]	validation_0-mae:560926	validation_1-mae:594244
# [620]	validation_0-mae:560872	validation_1-mae:594256
# [621]	validation_0-mae:560801	validation_1-mae:594247
# [622]	validation_0-mae:560747	validation_1-mae:594223
# [623]	validation_0-mae:560693	validation_1-mae:594219
# [624]	validation_0-mae:560619	validation_1-mae:594190
# [625]	validation_0-mae:560514	validation_1-mae:594184
# [626]	validation_0-mae:560417	validation_1-mae:594166
# [627]	validation_0-mae:560171	validation_1-mae:593941
# [628]	validation_0-mae:560067	validation_1-mae:593842
# [629]	validation_0-mae:559994	validation_1-mae:593776
# [630]	validation_0-mae:559933	validation_1-mae:593766
# [631]	validation_0-mae:559848	validation_1-mae:593774
# [632]	validation_0-mae:559790	validation_1-mae:593772
# [633]	validation_0-mae:559685	validation_1-mae:593710
# [634]	validation_0-mae:559603	validation_1-mae:593711
# [635]	validation_0-mae:559492	validation_1-mae:593663
# [636]	validation_0-mae:559429	validation_1-mae:593642
# [637]	validation_0-mae:559270	validation_1-mae:593535
# [638]	validation_0-mae:559221	validation_1-mae:593514
# [639]	validation_0-mae:559191	validation_1-mae:593531
# [640]	validation_0-mae:559147	validation_1-mae:593555
# [641]	validation_0-mae:559093	validation_1-mae:593559
# [642]	validation_0-mae:559028	validation_1-mae:593562
# [643]	validation_0-mae:558961	validation_1-mae:593533
# [644]	validation_0-mae:558792	validation_1-mae:593363
# [645]	validation_0-mae:558685	validation_1-mae:593318
# [646]	validation_0-mae:558638	validation_1-mae:593309
# [647]	validation_0-mae:558602	validation_1-mae:593293
# [648]	validation_0-mae:558573	validation_1-mae:593260
# [649]	validation_0-mae:558479	validation_1-mae:593189
# [650]	validation_0-mae:558326	validation_1-mae:593024
# [651]	validation_0-mae:558312	validation_1-mae:593034
# [652]	validation_0-mae:558253	validation_1-mae:592994
# [653]	validation_0-mae:558206	validation_1-mae:592979
# [654]	validation_0-mae:558187	validation_1-mae:592976
# [655]	validation_0-mae:558159	validation_1-mae:592963
# [656]	validation_0-mae:558128	validation_1-mae:592942
# [657]	validation_0-mae:558064	validation_1-mae:592909
# [658]	validation_0-mae:558026	validation_1-mae:592876
# [659]	validation_0-mae:557922	validation_1-mae:592859
# [660]	validation_0-mae:557874	validation_1-mae:592895
# [661]	validation_0-mae:557762	validation_1-mae:592786
# [662]	validation_0-mae:557713	validation_1-mae:592815
# [663]	validation_0-mae:557690	validation_1-mae:592822
# [664]	validation_0-mae:557647	validation_1-mae:592816
# [665]	validation_0-mae:557588	validation_1-mae:592831
# [666]	validation_0-mae:557535	validation_1-mae:592793
# [667]	validation_0-mae:557471	validation_1-mae:592787
# [668]	validation_0-mae:557364	validation_1-mae:592761
# [669]	validation_0-mae:557258	validation_1-mae:592703
# [670]	validation_0-mae:557188	validation_1-mae:592644
# [671]	validation_0-mae:557138	validation_1-mae:592629
# [672]	validation_0-mae:557092	validation_1-mae:592614
# [673]	validation_0-mae:557034	validation_1-mae:592628
# [674]	validation_0-mae:556965	validation_1-mae:592627
# [675]	validation_0-mae:556872	validation_1-mae:592555
# [676]	validation_0-mae:556842	validation_1-mae:592536
# [677]	validation_0-mae:556768	validation_1-mae:592459
# [678]	validation_0-mae:556702	validation_1-mae:592462
# [679]	validation_0-mae:556643	validation_1-mae:592449
# [680]	validation_0-mae:556546	validation_1-mae:592427
# [681]	validation_0-mae:556511	validation_1-mae:592428
# [682]	validation_0-mae:556468	validation_1-mae:592400
# [683]	validation_0-mae:556432	validation_1-mae:592424
# [684]	validation_0-mae:556334	validation_1-mae:592368
# [685]	validation_0-mae:556253	validation_1-mae:592376
# [686]	validation_0-mae:556199	validation_1-mae:592360
# [687]	validation_0-mae:556164	validation_1-mae:592382
# [688]	validation_0-mae:556124	validation_1-mae:592388
# [689]	validation_0-mae:556022	validation_1-mae:592331
# [690]	validation_0-mae:555873	validation_1-mae:592233
# [691]	validation_0-mae:555738	validation_1-mae:592178
# [692]	validation_0-mae:555681	validation_1-mae:592182
# [693]	validation_0-mae:555572	validation_1-mae:592122
# [694]	validation_0-mae:555513	validation_1-mae:592109
# [695]	validation_0-mae:555483	validation_1-mae:592108
# [696]	validation_0-mae:555421	validation_1-mae:592091
# [697]	validation_0-mae:555394	validation_1-mae:592157
# [698]	validation_0-mae:555283	validation_1-mae:592130
# [699]	validation_0-mae:555270	validation_1-mae:592126
# [700]	validation_0-mae:555220	validation_1-mae:592100
# [701]	validation_0-mae:555156	validation_1-mae:592085
# [702]	validation_0-mae:554845	validation_1-mae:591817
# [703]	validation_0-mae:554773	validation_1-mae:591798
# [704]	validation_0-mae:554628	validation_1-mae:591710
# [705]	validation_0-mae:554563	validation_1-mae:591727
# [706]	validation_0-mae:554398	validation_1-mae:591617
# [707]	validation_0-mae:554351	validation_1-mae:591586
# [708]	validation_0-mae:554234	validation_1-mae:591550
# [709]	validation_0-mae:554154	validation_1-mae:591506
# [710]	validation_0-mae:554111	validation_1-mae:591506
# [711]	validation_0-mae:553875	validation_1-mae:591312
# [712]	validation_0-mae:553854	validation_1-mae:591333
# [713]	validation_0-mae:553774	validation_1-mae:591267
# [714]	validation_0-mae:553729	validation_1-mae:591258
# [715]	validation_0-mae:553602	validation_1-mae:591216
# [716]	validation_0-mae:553545	validation_1-mae:591214
# [717]	validation_0-mae:553494	validation_1-mae:591155
# [718]	validation_0-mae:553453	validation_1-mae:591188
# [719]	validation_0-mae:553295	validation_1-mae:591098
# [720]	validation_0-mae:553232	validation_1-mae:591092
# [721]	validation_0-mae:553143	validation_1-mae:591052
# [722]	validation_0-mae:553082	validation_1-mae:591052
# [723]	validation_0-mae:552995	validation_1-mae:590993
# [724]	validation_0-mae:552936	validation_1-mae:590991
# [725]	validation_0-mae:552823	validation_1-mae:590927
# [726]	validation_0-mae:552710	validation_1-mae:590867
# [727]	validation_0-mae:552607	validation_1-mae:590806
# [728]	validation_0-mae:552561	validation_1-mae:590807
# [729]	validation_0-mae:552490	validation_1-mae:590832
# [730]	validation_0-mae:552426	validation_1-mae:590784
# [731]	validation_0-mae:552366	validation_1-mae:590761
# [732]	validation_0-mae:552306	validation_1-mae:590746
# [733]	validation_0-mae:552179	validation_1-mae:590703
# [734]	validation_0-mae:552131	validation_1-mae:590719
# [735]	validation_0-mae:552037	validation_1-mae:590694
# [736]	validation_0-mae:551945	validation_1-mae:590621
# [737]	validation_0-mae:551871	validation_1-mae:590596
# [738]	validation_0-mae:551818	validation_1-mae:590612
# [739]	validation_0-mae:551767	validation_1-mae:590604
# [740]	validation_0-mae:551712	validation_1-mae:590595
# [741]	validation_0-mae:551638	validation_1-mae:590554
# [742]	validation_0-mae:551554	validation_1-mae:590563
# [743]	validation_0-mae:551481	validation_1-mae:590551
# [744]	validation_0-mae:551398	validation_1-mae:590546
# [745]	validation_0-mae:551337	validation_1-mae:590551
# [746]	validation_0-mae:551276	validation_1-mae:590499
# [747]	validation_0-mae:551215	validation_1-mae:590499
# [748]	validation_0-mae:551052	validation_1-mae:590383
# [749]	validation_0-mae:551007	validation_1-mae:590394
# [750]	validation_0-mae:550931	validation_1-mae:590415
# [751]	validation_0-mae:550872	validation_1-mae:590404
# [752]	validation_0-mae:550815	validation_1-mae:590424
# [753]	validation_0-mae:550762	validation_1-mae:590399
# [754]	validation_0-mae:550679	validation_1-mae:590379
# [755]	validation_0-mae:550614	validation_1-mae:590381
# [756]	validation_0-mae:550570	validation_1-mae:590420
# [757]	validation_0-mae:550476	validation_1-mae:590374
# [758]	validation_0-mae:550412	validation_1-mae:590318
# [759]	validation_0-mae:550348	validation_1-mae:590297
# [760]	validation_0-mae:550231	validation_1-mae:590203
# [761]	validation_0-mae:550149	validation_1-mae:590172
# [762]	validation_0-mae:550073	validation_1-mae:590139
# [763]	validation_0-mae:550018	validation_1-mae:590131
# [764]	validation_0-mae:549899	validation_1-mae:590079
# [765]	validation_0-mae:549856	validation_1-mae:590119
# [766]	validation_0-mae:549810	validation_1-mae:590105
# [767]	validation_0-mae:549776	validation_1-mae:590106
# [768]	validation_0-mae:549693	validation_1-mae:590034
# [769]	validation_0-mae:549596	validation_1-mae:590004
# [770]	validation_0-mae:549561	validation_1-mae:590019
# [771]	validation_0-mae:549477	validation_1-mae:590007
# [772]	validation_0-mae:549433	validation_1-mae:589988
# [773]	validation_0-mae:549376	validation_1-mae:589971
# [774]	validation_0-mae:549313	validation_1-mae:589960
# [775]	validation_0-mae:549262	validation_1-mae:589948
# [776]	validation_0-mae:549193	validation_1-mae:589886
# [777]	validation_0-mae:549040	validation_1-mae:589780
# [778]	validation_0-mae:548972	validation_1-mae:589772
# [779]	validation_0-mae:548923	validation_1-mae:589787
# [780]	validation_0-mae:548879	validation_1-mae:589787
# [781]	validation_0-mae:548812	validation_1-mae:589818
# [782]	validation_0-mae:548653	validation_1-mae:589664
# [783]	validation_0-mae:548529	validation_1-mae:589571
# [784]	validation_0-mae:548488	validation_1-mae:589585
# [785]	validation_0-mae:548411	validation_1-mae:589566
# [786]	validation_0-mae:548337	validation_1-mae:589566
# [787]	validation_0-mae:548287	validation_1-mae:589549
# [788]	validation_0-mae:548205	validation_1-mae:589512
# [789]	validation_0-mae:548119	validation_1-mae:589479
# [790]	validation_0-mae:548022	validation_1-mae:589465
# [791]	validation_0-mae:547942	validation_1-mae:589457
# [792]	validation_0-mae:547855	validation_1-mae:589428
# [793]	validation_0-mae:547785	validation_1-mae:589407
# [794]	validation_0-mae:547766	validation_1-mae:589465
# [795]	validation_0-mae:547732	validation_1-mae:589470
# [796]	validation_0-mae:547652	validation_1-mae:589459
# [797]	validation_0-mae:547606	validation_1-mae:589464
# [798]	validation_0-mae:547516	validation_1-mae:589400
# [799]	validation_0-mae:547477	validation_1-mae:589392
# [800]	validation_0-mae:547396	validation_1-mae:589368
# [801]	validation_0-mae:547334	validation_1-mae:589381
# [802]	validation_0-mae:547272	validation_1-mae:589374
# [803]	validation_0-mae:547180	validation_1-mae:589363
# [804]	validation_0-mae:547090	validation_1-mae:589330
# [805]	validation_0-mae:547048	validation_1-mae:589323
# [806]	validation_0-mae:546944	validation_1-mae:589257
# [807]	validation_0-mae:546896	validation_1-mae:589242
# [808]	validation_0-mae:546789	validation_1-mae:589216
# [809]	validation_0-mae:546709	validation_1-mae:589197
# [810]	validation_0-mae:546586	validation_1-mae:589112
# [811]	validation_0-mae:546516	validation_1-mae:589092
# [812]	validation_0-mae:546416	validation_1-mae:589058
# [813]	validation_0-mae:546298	validation_1-mae:588958
# [814]	validation_0-mae:546184	validation_1-mae:588916
# [815]	validation_0-mae:546102	validation_1-mae:588892
# [816]	validation_0-mae:546025	validation_1-mae:588828
# [817]	validation_0-mae:545971	validation_1-mae:588855
# [818]	validation_0-mae:545951	validation_1-mae:588853
# [819]	validation_0-mae:545891	validation_1-mae:588864
# [820]	validation_0-mae:545805	validation_1-mae:588864
# [821]	validation_0-mae:545748	validation_1-mae:588866
# [822]	validation_0-mae:545637	validation_1-mae:588811
# [823]	validation_0-mae:545537	validation_1-mae:588768
# [824]	validation_0-mae:545453	validation_1-mae:588792
# [825]	validation_0-mae:545365	validation_1-mae:588777
# [826]	validation_0-mae:545303	validation_1-mae:588753
# [827]	validation_0-mae:545233	validation_1-mae:588790
# [828]	validation_0-mae:545218	validation_1-mae:588801
# [829]	validation_0-mae:545106	validation_1-mae:588748
# [830]	validation_0-mae:545039	validation_1-mae:588738
# [831]	validation_0-mae:544995	validation_1-mae:588721
# [832]	validation_0-mae:544926	validation_1-mae:588666
# [833]	validation_0-mae:544880	validation_1-mae:588663
# [834]	validation_0-mae:544783	validation_1-mae:588618
# [835]	validation_0-mae:544720	validation_1-mae:588594
# [836]	validation_0-mae:544678	validation_1-mae:588573
# [837]	validation_0-mae:544606	validation_1-mae:588554
# [838]	validation_0-mae:544565	validation_1-mae:588535
# [839]	validation_0-mae:544500	validation_1-mae:588540
# [840]	validation_0-mae:544424	validation_1-mae:588514
# [841]	validation_0-mae:544376	validation_1-mae:588545
# [842]	validation_0-mae:544316	validation_1-mae:588515
# [843]	validation_0-mae:544252	validation_1-mae:588484
# [844]	validation_0-mae:544171	validation_1-mae:588461
# [845]	validation_0-mae:544154	validation_1-mae:588480
# [846]	validation_0-mae:544075	validation_1-mae:588444
# [847]	validation_0-mae:544023	validation_1-mae:588406
# [848]	validation_0-mae:543909	validation_1-mae:588344
# [849]	validation_0-mae:543838	validation_1-mae:588287
# [850]	validation_0-mae:543684	validation_1-mae:588204
# [851]	validation_0-mae:543557	validation_1-mae:588080
# [852]	validation_0-mae:543485	validation_1-mae:588062
# [853]	validation_0-mae:543419	validation_1-mae:588015
# [854]	validation_0-mae:543363	validation_1-mae:587990
# [855]	validation_0-mae:543335	validation_1-mae:587994
# [856]	validation_0-mae:543251	validation_1-mae:587988
# [857]	validation_0-mae:543179	validation_1-mae:587969
# [858]	validation_0-mae:543126	validation_1-mae:587949
# [859]	validation_0-mae:543085	validation_1-mae:587962
# [860]	validation_0-mae:543000	validation_1-mae:587919
# [861]	validation_0-mae:542886	validation_1-mae:587865
# [862]	validation_0-mae:542826	validation_1-mae:587862
# [863]	validation_0-mae:542787	validation_1-mae:587840
# [864]	validation_0-mae:542729	validation_1-mae:587831
# [865]	validation_0-mae:542695	validation_1-mae:587859
# [866]	validation_0-mae:542642	validation_1-mae:587849
# [867]	validation_0-mae:542565	validation_1-mae:587808
# [868]	validation_0-mae:542494	validation_1-mae:587799
# [869]	validation_0-mae:542364	validation_1-mae:587775
# [870]	validation_0-mae:542302	validation_1-mae:587761
# [871]	validation_0-mae:542233	validation_1-mae:587753
# [872]	validation_0-mae:542162	validation_1-mae:587749
# [873]	validation_0-mae:542054	validation_1-mae:587702
# [874]	validation_0-mae:541983	validation_1-mae:587649
# [875]	validation_0-mae:541921	validation_1-mae:587646
# [876]	validation_0-mae:541844	validation_1-mae:587613
# [877]	validation_0-mae:541775	validation_1-mae:587619
# [878]	validation_0-mae:541730	validation_1-mae:587630
# [879]	validation_0-mae:541651	validation_1-mae:587587
# [880]	validation_0-mae:541632	validation_1-mae:587596
# [881]	validation_0-mae:541568	validation_1-mae:587574
# [882]	validation_0-mae:541517	validation_1-mae:587548
# [883]	validation_0-mae:541479	validation_1-mae:587573
# [884]	validation_0-mae:541437	validation_1-mae:587564
# [885]	validation_0-mae:541388	validation_1-mae:587550
# [886]	validation_0-mae:541329	validation_1-mae:587523
# [887]	validation_0-mae:541257	validation_1-mae:587493
# [888]	validation_0-mae:541210	validation_1-mae:587466
# [889]	validation_0-mae:541178	validation_1-mae:587464
# [890]	validation_0-mae:541117	validation_1-mae:587458
# [891]	validation_0-mae:541085	validation_1-mae:587469
# [892]	validation_0-mae:541050	validation_1-mae:587453
# [893]	validation_0-mae:540974	validation_1-mae:587388
# [894]	validation_0-mae:540886	validation_1-mae:587356
# [895]	validation_0-mae:540825	validation_1-mae:587321
# [896]	validation_0-mae:540742	validation_1-mae:587283
# [897]	validation_0-mae:540684	validation_1-mae:587274
# [898]	validation_0-mae:540589	validation_1-mae:587226
# [899]	validation_0-mae:540514	validation_1-mae:587231
# [900]	validation_0-mae:540434	validation_1-mae:587238
# [901]	validation_0-mae:540363	validation_1-mae:587214
# [902]	validation_0-mae:540296	validation_1-mae:587151
# [903]	validation_0-mae:540242	validation_1-mae:587161
# [904]	validation_0-mae:540159	validation_1-mae:587136
# [905]	validation_0-mae:540109	validation_1-mae:587113
# [906]	validation_0-mae:540058	validation_1-mae:587076
# [907]	validation_0-mae:539997	validation_1-mae:587033
# [908]	validation_0-mae:539929	validation_1-mae:587026
# [909]	validation_0-mae:539841	validation_1-mae:586970
# [910]	validation_0-mae:539790	validation_1-mae:586982
# [911]	validation_0-mae:539739	validation_1-mae:586970
# [912]	validation_0-mae:539670	validation_1-mae:586937
# [913]	validation_0-mae:539623	validation_1-mae:586950
# [914]	validation_0-mae:539556	validation_1-mae:586916
# [915]	validation_0-mae:539496	validation_1-mae:586909
# [916]	validation_0-mae:539456	validation_1-mae:586923
# [917]	validation_0-mae:539399	validation_1-mae:586893
# [918]	validation_0-mae:539354	validation_1-mae:586891
# [919]	validation_0-mae:539212	validation_1-mae:586809
# [920]	validation_0-mae:539175	validation_1-mae:586823
# [921]	validation_0-mae:539085	validation_1-mae:586742
# [922]	validation_0-mae:538989	validation_1-mae:586689
# [923]	validation_0-mae:538931	validation_1-mae:586642
# [924]	validation_0-mae:538871	validation_1-mae:586634
# [925]	validation_0-mae:538792	validation_1-mae:586607
# [926]	validation_0-mae:538709	validation_1-mae:586574
# [927]	validation_0-mae:538658	validation_1-mae:586551
# [928]	validation_0-mae:538609	validation_1-mae:586538
# [929]	validation_0-mae:538558	validation_1-mae:586542
# [930]	validation_0-mae:538481	validation_1-mae:586538
# [931]	validation_0-mae:538434	validation_1-mae:586546
# [932]	validation_0-mae:538255	validation_1-mae:586396
# [933]	validation_0-mae:538206	validation_1-mae:586382
# [934]	validation_0-mae:538128	validation_1-mae:586367
# [935]	validation_0-mae:538085	validation_1-mae:586382
# [936]	validation_0-mae:538018	validation_1-mae:586339
# [937]	validation_0-mae:537972	validation_1-mae:586329
# [938]	validation_0-mae:537887	validation_1-mae:586307
# [939]	validation_0-mae:537810	validation_1-mae:586259
# [940]	validation_0-mae:537779	validation_1-mae:586285
# [941]	validation_0-mae:537661	validation_1-mae:586184
# [942]	validation_0-mae:537601	validation_1-mae:586127
# [943]	validation_0-mae:537526	validation_1-mae:586073
# [944]	validation_0-mae:537453	validation_1-mae:586030
# [945]	validation_0-mae:537278	validation_1-mae:585916
# [946]	validation_0-mae:537209	validation_1-mae:585888
# [947]	validation_0-mae:537088	validation_1-mae:585781
# [948]	validation_0-mae:537032	validation_1-mae:585758
# [949]	validation_0-mae:536972	validation_1-mae:585754
# [950]	validation_0-mae:536950	validation_1-mae:585755
# [951]	validation_0-mae:536879	validation_1-mae:585744
# [952]	validation_0-mae:536789	validation_1-mae:585710
# [953]	validation_0-mae:536722	validation_1-mae:585712
# [954]	validation_0-mae:536667	validation_1-mae:585709
# [955]	validation_0-mae:536609	validation_1-mae:585671
# [956]	validation_0-mae:536551	validation_1-mae:585638
# [957]	validation_0-mae:536519	validation_1-mae:585654
# [958]	validation_0-mae:536447	validation_1-mae:585631
# [959]	validation_0-mae:536382	validation_1-mae:585624
# [960]	validation_0-mae:536371	validation_1-mae:585632
# [961]	validation_0-mae:536309	validation_1-mae:585604
# [962]	validation_0-mae:536257	validation_1-mae:585624
# [963]	validation_0-mae:536185	validation_1-mae:585582
# [964]	validation_0-mae:536100	validation_1-mae:585485
# [965]	validation_0-mae:536046	validation_1-mae:585443
# [966]	validation_0-mae:535992	validation_1-mae:585432
# [967]	validation_0-mae:535946	validation_1-mae:585411
# [968]	validation_0-mae:535889	validation_1-mae:585407
# [969]	validation_0-mae:535812	validation_1-mae:585405
# [970]	validation_0-mae:535703	validation_1-mae:585337
# [971]	validation_0-mae:535634	validation_1-mae:585309
# [972]	validation_0-mae:535617	validation_1-mae:585316
# [973]	validation_0-mae:535564	validation_1-mae:585315
# [974]	validation_0-mae:535522	validation_1-mae:585323
# [975]	validation_0-mae:535446	validation_1-mae:585310
# [976]	validation_0-mae:535402	validation_1-mae:585330
# [977]	validation_0-mae:535343	validation_1-mae:585338
# [978]	validation_0-mae:535294	validation_1-mae:585377
# [979]	validation_0-mae:535250	validation_1-mae:585360
# [980]	validation_0-mae:535214	validation_1-mae:585353
# [981]	validation_0-mae:535107	validation_1-mae:585277
# [982]	validation_0-mae:535061	validation_1-mae:585266
# [983]	validation_0-mae:535006	validation_1-mae:585276
# [984]	validation_0-mae:534936	validation_1-mae:585253
# [985]	validation_0-mae:534903	validation_1-mae:585255
# [986]	validation_0-mae:534865	validation_1-mae:585262
# [987]	validation_0-mae:534818	validation_1-mae:585247
# [988]	validation_0-mae:534699	validation_1-mae:585206
# [989]	validation_0-mae:534593	validation_1-mae:585133
# [990]	validation_0-mae:534535	validation_1-mae:585116
# [991]	validation_0-mae:534460	validation_1-mae:585107
# [992]	validation_0-mae:534383	validation_1-mae:585088
# [993]	validation_0-mae:534296	validation_1-mae:585091
# [994]	validation_0-mae:534259	validation_1-mae:585078
# [995]	validation_0-mae:534169	validation_1-mae:585032
# [996]	validation_0-mae:534112	validation_1-mae:585003
# [997]	validation_0-mae:534039	validation_1-mae:584950
# [998]	validation_0-mae:533965	validation_1-mae:584930
# [999]	validation_0-mae:533906	validation_1-mae:584902

# %%
results = model.evals_result()
display("Maxima diferencia al final: " + str(results['validation_1']['mae'][-1] - results['validation_0']['mae'][-1]))
epochs = len(results['validation_0']['mae'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['mae'], label='Train')
ax.plot(x_axis, results['validation_1']['mae'], label='Test')
ax.legend()
plt.ylabel('mae')
plt.title('XGBoost mae')
# Out:
# 'Maxima diferencia al final: 50996.5625'
# Text(0.5, 1.0, 'XGBoost mae')

# %%
from sklearn.model_selection import KFold
numFolds = 5
folds = KFold(n_splits = numFolds, shuffle = True)

entrenamiento = df.head(240000).copy()
X = entrenamiento[features].copy()
y = entrenamiento.precio.copy()
estimators = []
results = np.zeros(len(train_x))
score = 0.0
for train_index, test_index in folds.split(X):
    X_train, X_test = X.iloc[train_index,:], X.iloc[test_index,:]
    y_train, y_test = y.iloc[train_index].values.ravel(), y.iloc[test_index].values.ravel()
    my_pipeline.fit(X_train, y_train)

    estimators.append(my_pipeline)
    results[test_index] = my_pipeline.predict(X_test)
    score += mean_absolute_error(y_test, results[test_index])
score /= numFolds
ping()
score
# Out:
# Fold actual: [192000 - 48000]
# [18:12:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Fold actual: [192000 - 48000]
# [18:12:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Fold actual: [192000 - 48000]
# [18:12:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Fold actual: [192000 - 48000]
# [18:13:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
mean_absolute_error(results, y)
# Out:
# 585510.4182892172

# %%
estimators
# Out:
# [Pipeline(memory=None,
#           steps=[('preprocessor',
#                   ColumnTransformer(n_jobs=None, remainder='drop',
#                                     sparse_threshold=0.3,
#                                     transformer_weights=None,
#                                     transformers=[('num',
#                                                    Pipeline(memory=None,
#                                                             steps=[('a',
#                                                                     SimpleImputer(add_indicator=False,
#                                                                                   copy=True,
#                                                                                   fill_value=None,
#                                                                                   missing_values=nan,
#                                                                                   strategy='median',
#                                                                                   verbose=0))],
#                                                             verbose=False),
#                                                    ['id', 'antiguedad',
#                                                     'habitaciones',...
#                                colsample_bytree=0.75, eval_metric='mae',
#                                gamma=0.0, gpu_id=0, importance_type='gain',
#                                learning_rate=0.1, max_delta_step=0, max_depth=5,
#                                min_child_weight=3, missing=None,
#                                n_estimators=1000, n_jobs=1, nthread=None,
#                                objective='reg:linear', random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=2,
#                                seed=None, silent=None, subsample=0.7,
#                                tree_method='gpu_hist', verbosity=1))],
#           verbose=False), Pipeline(memory=None,
#           steps=[('preprocessor',
#                   ColumnTransformer(n_jobs=None, remainder='drop',
#                                     sparse_threshold=0.3,
#                                     transformer_weights=None,
#                                     transformers=[('num',
#                                                    Pipeline(memory=None,
#                                                             steps=[('a',
#                                                                     SimpleImputer(add_indicator=False,
#                                                                                   copy=True,
#                                                                                   fill_value=None,
#                                                                                   missing_values=nan,
#                                                                                   strategy='median',
#                                                                                   verbose=0))],
#                                                             verbose=False),
#                                                    ['id', 'antiguedad',
#                                                     'habitaciones',...
#                                colsample_bytree=0.75, eval_metric='mae',
#                                gamma=0.0, gpu_id=0, importance_type='gain',
#                                learning_rate=0.1, max_delta_step=0, max_depth=5,
#                                min_child_weight=3, missing=None,
#                                n_estimators=1000, n_jobs=1, nthread=None,
#                                objective='reg:linear', random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=2,
#                                seed=None, silent=None, subsample=0.7,
#                                tree_method='gpu_hist', verbosity=1))],
#           verbose=False), Pipeline(memory=None,
#           steps=[('preprocessor',
#                   ColumnTransformer(n_jobs=None, remainder='drop',
#                                     sparse_threshold=0.3,
#                                     transformer_weights=None,
#                                     transformers=[('num',
#                                                    Pipeline(memory=None,
#                                                             steps=[('a',
#                                                                     SimpleImputer(add_indicator=False,
#                                                                                   copy=True,
#                                                                                   fill_value=None,
#                                                                                   missing_values=nan,
#                                                                                   strategy='median',
#                                                                                   verbose=0))],
#                                                             verbose=False),
#                                                    ['id', 'antiguedad',
#                                                     'habitaciones',...
#                                colsample_bytree=0.75, eval_metric='mae',
#                                gamma=0.0, gpu_id=0, importance_type='gain',
#                                learning_rate=0.1, max_delta_step=0, max_depth=5,
#                                min_child_weight=3, missing=None,
#                                n_estimators=1000, n_jobs=1, nthread=None,
#                                objective='reg:linear', random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=2,
#                                seed=None, silent=None, subsample=0.7,
#                                tree_method='gpu_hist', verbosity=1))],
#           verbose=False), Pipeline(memory=None,
#           steps=[('preprocessor',
#                   ColumnTransformer(n_jobs=None, remainder='drop',
#                                     sparse_threshold=0.3,
#                                     transformer_weights=None,
#                                     transformers=[('num',
#                                                    Pipeline(memory=None,
#                                                             steps=[('a',
#                                                                     SimpleImputer(add_indicator=False,
#                                                                                   copy=True,
#                                                                                   fill_value=None,
#                                                                                   missing_values=nan,
#                                                                                   strategy='median',
#                                                                                   verbose=0))],
#                                                             verbose=False),
#                                                    ['id', 'antiguedad',
#                                                     'habitaciones',...
#                                colsample_bytree=0.75, eval_metric='mae',
#                                gamma=0.0, gpu_id=0, importance_type='gain',
#                                learning_rate=0.1, max_delta_step=0, max_depth=5,
#                                min_child_weight=3, missing=None,
#                                n_estimators=1000, n_jobs=1, nthread=None,
#                                objective='reg:linear', random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=2,
#                                seed=None, silent=None, subsample=0.7,
#                                tree_method='gpu_hist', verbosity=1))],
#           verbose=False), Pipeline(memory=None,
#           steps=[('preprocessor',
#                   ColumnTransformer(n_jobs=None, remainder='drop',
#                                     sparse_threshold=0.3,
#                                     transformer_weights=None,
#                                     transformers=[('num',
#                                                    Pipeline(memory=None,
#                                                             steps=[('a',
#                                                                     SimpleImputer(add_indicator=False,
#                                                                                   copy=True,
#                                                                                   fill_value=None,
#                                                                                   missing_values=nan,
#                                                                                   strategy='median',
#                                                                                   verbose=0))],
#                                                             verbose=False),
#                                                    ['id', 'antiguedad',
#                                                     'habitaciones',...
#                                colsample_bytree=0.75, eval_metric='mae',
#                                gamma=0.0, gpu_id=0, importance_type='gain',
#                                learning_rate=0.1, max_delta_step=0, max_depth=5,
#                                min_child_weight=3, missing=None,
#                                n_estimators=1000, n_jobs=1, nthread=None,
#                                objective='reg:linear', random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=2,
#                                seed=None, silent=None, subsample=0.7,
#                                tree_method='gpu_hist', verbosity=1))],
#           verbose=False)]
